# %%
import pandas as pd

# %%
df = pd.read_csv('fifa18_clean.csv')

# %%
df.head()
# Out:
#    Wage (€)  Value (€)               Name  Age  \
# 0    565000   95500000  Cristiano Ronaldo   32
# 1    565000  105000000           L. Messi   30
# 2    280000  123000000             Neymar   25
# 3    510000   97000000          L. Suárez   30
# 4    230000   61000000           M. Neuer   31
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/38.png       94         94
# 1  https://cdn.sofifa.org/flags/52.png       93         93
# 2  https://cdn.sofifa.org/flags/54.png       92         94
# ...

# %%
df.drop(columns=columns_to_drop, inplace=True)

# %%
df.head()
# Out:
#    Wage (€)  Value (€)               Name  Age Nationality  Overall  \
# 0    565000   95500000  Cristiano Ronaldo   32    Portugal       94
# 1    565000  105000000           L. Messi   30   Argentina       93
# 2    280000  123000000             Neymar   25      Brazil       92
# 3    510000   97000000          L. Suárez   30     Uruguay       92
# 4    230000   61000000           M. Neuer   31     Germany       92
#
#    Potential  Special  Acceleration  Aggression  ...  Shot power  \
# 0         94     2228          89.0        63.0  ...        94.0
# 1         93     2154          92.0        48.0  ...        85.0
# 2         94     2100          94.0        56.0  ...        80.0
# 3         92     2291          88.0        78.0  ...        87.0
# 4         92     1493          58.0        29.0  ...        25.0
#
#    Sliding tackle  Sprint speed  Stamina  Standing tackle  Strength  Vision  \
# 0            23.0          91.0     92.0             31.0      80.0    85.0
# ...

# %%
df['Preferred Positions'] = df['Preferred Positions'].str.split().str[0]

# %%
df['Preferred Positions']
# Out:
# 0        ST
# 1        RW
# 2        LW
# 3        ST
# 4        GK
#          ..
# 17976    GK
# 17977    GK
# 17978    ST
# 17979    CM
# 17980    ST
# Name: Preferred Positions, Length: 17981, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 44 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Wage (€)             17981 non-null  int64
#  1   Value (€)            17981 non-null  int64
#  2   Name                 17981 non-null  object
#  3   Age                  17981 non-null  int64
#  4   Nationality          17981 non-null  object
#  5   Overall              17981 non-null  int64
#  6   Potential            17981 non-null  int64
#  7   Special              17981 non-null  int64
#  8   Acceleration         17897 non-null  float64
#  9   Aggression           17913 non-null  float64
#  10  Agility              17910 non-null  float64
#  11  Balance              17924 non-null  float64
#  12  Ball control         17840 non-null  float64
#  13  Composure            17887 non-null  float64
#  14  Crossing             17885 non-null  float64
# ...

# %%
df.describe()
# Out:
#             Wage (€)     Value (€)           Age       Overall     Potential  \
# count   17981.000000  1.798100e+04  17981.000000  17981.000000  17981.000000
# mean    11546.966242  2.385390e+06     25.144541     66.247984     71.190813
# std     23080.000139  5.353970e+06      4.614272      6.987965      6.102199
# min         0.000000  0.000000e+00     16.000000     46.000000     46.000000
# 25%      2000.000000  3.000000e+05     21.000000     62.000000     67.000000
# 50%      4000.000000  6.750000e+05     25.000000     66.000000     71.000000
# 75%     12000.000000  2.100000e+06     28.000000     71.000000     75.000000
# max    565000.000000  1.230000e+08     47.000000     94.000000     94.000000
#
#             Special  Acceleration    Aggression       Agility       Balance  \
# count  17981.000000  17897.000000  17913.000000  17910.000000  17924.000000
# mean    1594.095100     64.576521     55.791492     63.333613     63.803894
# ...

# %%
df.isnull().sum()
# Out:
# Wage (€)                 0
# Value (€)                0
# Name                     0
# Age                      0
# Nationality              0
# Overall                  0
# Potential                0
# Special                  0
# Acceleration            84
# Aggression              68
# Agility                 71
# Balance                 57
# Ball control           141
# Composure               94
# Crossing                96
# Curve                   73
# Dribbling              131
# Finishing              114
# Free kick accuracy      49
# GK diving               26
# GK handling             27
# GK kicking              19
# GK positioning          26
# GK reflexes             29
# Heading accuracy        75
# Interceptions          100
# Jumping                 70
# Long passing           121
# Long shots              83
# Marking                112
# Penalties               30
# Positioning             95
# Reactions              115
# Short passing          149
# ...

# %%
df.to_csv('new_fifa1.csv', index=False)

# %%
df[df['Name'] == 'L. Messi']['Nationality']
# Out:
# 1    Argentina
# Name: Nationality, dtype: object

# %%
df.head(10)
# Out:
#    Wage (€)  Value (€)               Name  Age Nationality  Overall  \
# 0    565000   95500000  Cristiano Ronaldo   32    Portugal       94
# 1    565000  105000000           L. Messi   30   Argentina       93
# 2    280000  123000000             Neymar   25      Brazil       92
# 3    510000   97000000          L. Suárez   30     Uruguay       92
# 4    230000   61000000           M. Neuer   31     Germany       92
# 5    355000   92000000     R. Lewandowski   28      Poland       91
# 6    215000   64500000             De Gea   26       Spain       90
# 7    295000   90500000          E. Hazard   26     Belgium       90
# 8    340000   79000000           T. Kroos   27     Germany       90
# 9    275000   77000000         G. Higuaín   29   Argentina       90
#
#    Potential  Special  Acceleration  Aggression  ...  Shot power  \
# 0         94     2228          89.0        63.0  ...        94.0
# 1         93     2154          92.0        48.0  ...        85.0
# ...
